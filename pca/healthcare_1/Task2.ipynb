# %% [markdown]
# # Introduction to Customer Segmentation in Python
#
# ## Task 2: Exploratory Data Analysis
# Let's take a closer look at our data!

# %%
import pandas as pd

import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import seaborn as sns

# %%
df = pd.read_csv('Data/widget_processed.csv', index_col=0)

# %%
df.head()
# Out:
#   Brand Age Range Condition  Gender        Country   Total Cost  \
# 0   ABC      0-18       New  Female      Australia   484.444557
# 1   ABC      0-18       New  Female        Germany   201.362885
# 2   ABC      0-18       New  Female    Philippines    40.061676
# 3   ABC      0-18       New  Female  United States  2322.470261
# 4   ABC      0-18       New    Male      Australia  4036.793526
#
#    Total Quantity  Total Revenue  Total Visit ID
# 0               0       0.000000         1289090
# 1               0       0.000000          244027
# 2               1      40.061676           25537
# 3               0       0.000000         3531062
# 4               2     465.174522         1265656

# %%
df.Country.value_counts()
# Out:
# United States     737
# Germany           437
# United Kingdom    415
# Australia         197
# Canada            164
#                  ...
# Malawi              1
# Guyana              1
# Gibraltar           1
# American Samoa      1
# Ethiopia            1
# Name: Country, Length: 165, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           5000 non-null   object
#  1   Age Range       5000 non-null   object
#  2   Condition       5000 non-null   object
#  3   Gender          5000 non-null   object
#  4   Country         5000 non-null   object
#  5   Total Cost      5000 non-null   float64
#  6   Total Quantity  5000 non-null   int64
#  7   Total Revenue   5000 non-null   float64
#  8   Total Visit ID  5000 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 390.6+ KB

# %%
df.head()
# Out:
#   Brand Age Range Condition  Gender        Country   Total Cost  \
# 0   ABC      0-18       New  Female      Australia   484.444557
# 1   ABC      0-18       New  Female        Germany   201.362885
# 2   ABC      0-18       New  Female    Philippines    40.061676
# 3   ABC      0-18       New  Female  United States  2322.470261
# 4   ABC      0-18       New    Male      Australia  4036.793526
#
#    Total Quantity  Total Revenue  Total Visit ID
# 0               0       0.000000         1289090
# 1               0       0.000000          244027
# 2               1      40.061676           25537
# 3               0       0.000000         3531062
# 4               2     465.174522         1265656

# %%
df.Brand.value_counts()
# Out:
# APPLES                              2297
# ABC                                 1203
# Adzapantor                           201
# Adkilewor WorldWide Corp.            200
# Adnipax Direct                       144
#                                     ...
# Adcadican WorldWide                    1
# Adhupupantor International Corp.       1
# Adsapedgover Direct                    1
# Adjuban  Company                       1
# Adnipicover Direct                     1
# Name: Brand, Length: 77, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Brand',
#  'Age Range',
#  'Condition',
#  'Gender',
#  'Country',
#  'Total Cost',
#  'Total Quantity',
#  'Total Revenue',
#  'Total Visit ID']

# %%
features = [
    'Brand',
 'Age Range',
 'Condition',
 'Gender',
 'Country',
 'Total Cost',
 'Total Quantity',
 'Total Revenue',
 'Total Visit ID'
]
df[features].describe()
# Out:
#           Total Cost  Total Quantity  Total Revenue  Total Visit ID
# count    5000.000000     5000.000000   5.000000e+03    5.000000e+03
# mean     5962.604832        3.009000   1.727542e+03    6.241631e+06
# std     39639.603885       19.536501   2.093283e+04    4.132240e+07
# min         0.732225        0.000000   0.000000e+00    1.100000e+01
# 25%       132.931419        0.000000   0.000000e+00    3.014812e+05
# 50%       380.098557        0.000000   0.000000e+00    5.884275e+05
# 75%      1138.626823        1.000000   9.455860e+01    1.414957e+06
# max    886377.823946      537.000000   1.149108e+06    1.172637e+09

# %%
fig, axes = plt.subplots(2, 4, figsize=(15, 8))

for feature, ax in zip(features, axes.ravel()):
    if (feature=='Brand') | (feature=='Country'):
        df[feature].value_counts().plot.bar(ax=ax)
    else:
        ax.hist(df[feature], bins=100)
    ax.set_title(feature)
plt.tight_layout()

# %%
sns.pairplot?

# %%
pplot = sns.pairplot(df, vars=features[2:])
pplot.fig.set_size_inches(8, 8)
